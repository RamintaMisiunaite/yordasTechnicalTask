# %% [markdown]
# ## Since I come from a programming background I chose to do this task with Python.
# ## Firstly, I split the pdf file with https://www.pdf2go.com/split-pdf online tool to only keep the Annex A that I require. Then I extracted the data from the Annex with Excel's feature to get data from pdf files. All tables from different pages were in separate sheets, so I merged them all with the Ablebits Data-Merge tables tool.
#
# ## Once I had all the data I needed, I started this Jupyter notebook to clean and process it. If records had the same CAS number, I joined the records and separated them with ' | ' sign.
#
# ## For the processing of the Hazard class column, I chose to use get_close_matches method to try to identify which 'Field key' entry is the 'short version' closest to. As I didn't get a satisfactory result at first, I updated the entries in the Hazard class column to contain the full name of the field key, so the close match function would have better accuracy.
#
# ## I assigned each CAS No. which hazard types they have and inputted 'Category' into those fields. find_close_with_numbers finds the hazard type and the category number, however, I couldn't find a way to input the number into the table.
#
# ## In the final output excel file, I kept the hazard class column, so it would be visible that I have merged the chemicals
#
#
# ## Having finished the task I would like to reflect on what went well and what was more challenging. I'm happy about my data pre-processing skills, my use of dictionaries and the way I assigned Field keys to shorter versions of them. Also, I have improved my excel skills. I have never worked with data from pdf files, so I'm glad that now I know how to get data from them in Excel, as well as merge a lot of sheets into one.
#
# ## However, I wish I could've come up with a better way to present duplicate CAS no. combination of cells and actually demonstrate classification levels in the table. Also, the Field key association still misses a few Hazard types so I'd like to improve that.
#
#
# ## If this implementation was to be improved for speed, I believe I would need to make the data cleaning part more efficient and automated. Overall this whole code should be made into a 'data pipeline' and more adaptable/diverse for a more broad range of data.

# %%
import pandas as pd
 
pd.options.mode.chained_assignment = None

# %%
# read file
df = pd.read_excel('full_data.xlsm', header=1)
df
# Out:
#         Index No.                                      Chemical name  \
# 0    607-002-00-6  Acetic acid, concentration\n> 10 % < 80 % acid...
# 1    607-002-00-6   Acetic acid, concentration  10 % acid,\nby mass
# 2    607-002-00-6  Acetic acid, glacial, concentration\n> 80 % ac...
# 3    605-015-00-1                                             Acetal
# 4    605-003-00-6                                       Acetaldehyde
# ..            ...                                                ...
# 888  030-001-00-1                         Zinc dust, see Zinc powder
# 889  015-006-00-9                                     Zinc phosphide
# 890  030-001-00-1                                        Zinc powder
# 891  040-002-00-9                              Zirconium powder, dry
# 892  040-002-00-9  Zirconium, dry finished sheets, strips or\ncoi...
#
#        CAS No. UN\nNo.                                       Hazard class  \
# 0      64-19-7    2790                                       Skin corr 1B
# 1      64-19-7      –                                    Skin irritant 2
# 2      64-19-7    2789                        Flam liquid 3\nSkin corr 1B
# 3     105-57-7    1088    Flam liquid 2\nEye irritant 2A\nSkin irritant 2
# 4      75-07-0    1089  Flam liquid 1\nCarcinogen 2\nEye irritant 2A\n...
# ..         ...     ...                                                ...
# 888  7440-66-6     NaN                                                NaN
# 889  1314-84-7    1714  Water-react 1\nAcute tox 2\n(oral)\nAcute aqua...
# 890  7440-66-6    1436  Water-react 1\nPyro solid 1\nAcute aquatic 1\n...
# 891  7440-67-7    2008                                       Pyro solid 1
# 892  7440-67-7    2009                                       Flam solid 2
#
#     GHS\npictograms\non labels Signal\nword Hazard\nstatement\ncode(s)  \
# 0                    Corrosion       Danger                       H314
# 1            Exclamation\nmark      Warning                       H315
# 2             Flame\nCorrosion       Danger                 H226\nH314
# 3     Flame\nExclamation\nmark      Warning           H225\nH319\nH315
# 4            Flame\nHealth haz       Danger     H224\nH351\nH319\nH335
# ..                         ...          ...                        ...
# 888                        NaN          NaN                        NaN
# 889  Flame\nToxic\nEnviron haz       Danger     H260\nH300\nH400\nH410
# 890         Flame\nEnviron haz       Danger     H260\nH250\nH401\nH410
# 891                      Flame       Danger                       H250
# 892                      Flame      Warning                       H228
#
#                         Precautionary\nstatement codes  \
# 0    P260; P262; P264;\nP280;\nP303+P361+P353;\nP30...
# 1       P264; P280;\nP302+P352; P321;\nP332+P313; P362
# 2    P210; P233; P242;\nP243; P260; P262;\nP264; P2...
# 3    P210; P233; P242;\nP243; P264; P280;\nP305+P35...
# 4    P201; P202; P210;\nP233; P240; P241;\nP242; P2...
# ..                                                 ...
# 888                                                NaN
# 889  P223; P264; P270;\nP273; P280; P321;\nP391; P2...
# 890  P210; P222; P273;\nP280; P391;\nP335+P334;\nP3...
# 891     P210; P222; P280;\nP335+P334;\nP370+P378; P422
# 892                 P210; P240; P241;\nP280; P370+P378
#
#                              NOTES
# 0                              NaN
# 1    Not dangerous for\ntransport.
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ..                             ...
# 888                            NaN
# 889                            NaN
# 890                            NaN
# 891                            NaN
# 892                            NaN
#
# [893 rows x 10 columns]

# %%
columns = ['Index No.', 'Chemical name','CAS No.','Hazard class','NOTES']
df = df[columns]

# %%
# fill nan values with empty cell
df['Hazard class'] = df['Hazard class'].fillna(' ')

# %%
duplicate = df[df.duplicated(subset='CAS No.')]

# %%
# replace \n in the data
df['Chemical name'] = df['Chemical name'].replace({r'\s+$': '', r'^\s+': ''}, regex=True).replace(r'\n',  ' ', regex=True)

# %%
df['Hazard class'] = df['Hazard class'].replace({r'\s+$': '', r'^\s+': ''}, regex=True).replace(r'\n',  ',', regex=True)

# %%
df['NOTES'] = df['NOTES'].replace({r'\s+$': '', r'^\s+': ''}, regex=True).replace(r'\n',  ' ', regex=True)

# %%
df['NOTES'] = df['NOTES'].fillna(" ")

# %%
temp = df

# %%
temp
# Out:
#         Index No.                                      Chemical name  \
# 0    607-002-00-6  Acetic acid, concentration > 10 % < 80 % acid,...
# 1    607-002-00-6    Acetic acid, concentration  10 % acid, by mass
# 2    607-002-00-6  Acetic acid, glacial, concentration > 80 % aci...
# 3    605-015-00-1                                             Acetal
# 4    605-003-00-6                                       Acetaldehyde
# ..            ...                                                ...
# 888  030-001-00-1                         Zinc dust, see Zinc powder
# 889  015-006-00-9                                     Zinc phosphide
# 890  030-001-00-1                                        Zinc powder
# 891  040-002-00-9                              Zirconium powder, dry
# 892  040-002-00-9  Zirconium, dry finished sheets, strips or coil...
#
#        CAS No.                                       Hazard class  \
# 0      64-19-7                                       Skin corr 1B
# 1      64-19-7                                    Skin irritant 2
# 2      64-19-7                         Flam liquid 3,Skin corr 1B
# 3     105-57-7      Flam liquid 2,Eye irritant 2A,Skin irritant 2
# 4      75-07-0  Flam liquid 1,Carcinogen 2,Eye irritant 2A,STO...
# ..         ...                                                ...
# 888  7440-66-6
# 889  1314-84-7  Water-react 1,Acute tox 2,(oral),Acute aquatic...
# 890  7440-66-6  Water-react 1,Pyro solid 1,Acute aquatic 1,Chr...
# 891  7440-67-7                                       Pyro solid 1
# 892  7440-67-7                                       Flam solid 2
#
#                             NOTES
# 0
# 1    Not dangerous for transport.
# 2
# 3
# 4
# ..                            ...
# 888
# 889
# 890
# 891
# 892
#
# [893 rows x 5 columns]

# %%
# joining duplicates 
d= temp.groupby(['CAS No.'],as_index = False).agg({'Chemical name':' | '.join,
                                                          'Hazard class':' | '.join,
                                                          'NOTES':' | '.join,
                                                         })

# %%
df1 = pd.DataFrame(data=d)
df1
# Out:
#       CAS No.                                      Chemical name  \
# 0      192337  Butyl 2,3-epoxypropyl ether, see Butyl glycidy...
# 1      292142  Cyclohexylidene hydroperoxide, see Cyclohexano...
# 2      698078                                 Potassium chlorate
# 3     1304222  Hydroxylamine hydrochloride, see Hydroxylammon...
# 4     1817789       trans-1-Methyl-4-(1-methylvinyl) cyclohexene
# ..        ...                                                ...
# 528   99-35-4  1,3,5-Trinitrobenzene, dry or wetted with less...
# 529  993-16-8      Methyltin trichloride | Methyltin trichloride
# 530   CAS No.                                      Chemical name
# 531         t  Diactoxydibuytyl stannane, see Dibutyl-tin di(...
# 532        –  Aluminium alkyls | Aluminium powder (stabilize...
#
#                                           Hazard class  \
# 0     | Flam liquid 3,Carcinogen 2,Mutagen 2,Skin s...
# 1
# 2                           Oxid solid 1,Chron aquat 2
# 3                                       | Metal corr 1
# 4    Flam liquid 3,Skin irritant 2,Skin sens 1,Acut...
# ..                                                 ...
# 528  Explosive 1.1D,Acute tox 3,(oral),Acute aquati...
# 529                  Mutagen 2,Repod tox 2 | Mutagen 2
# 530                                       Hazard class
# 531
# 532  Pyro liquid 1,Skin corr 1B | Water-react 2,Fla...
#
#                                                  NOTES
# 0                                                  |
# 1
# 2    A powerful oxidizer and vey reactive material....
# 3                                                  |
# 4
# ..                                                 ...
# 528  A powerful high explosive that has more shatte...
# 529  Not hazardous for transport. | Not hazardous f...
# 530                                              NOTES
# 531
# 532    |   |   |   |   |   |   |   | This classific...
#
# [533 rows x 4 columns]

# %%
file = 'Output template - Data Technician exercise.xlsx'

# %%
ot = pd.read_excel(file,sheet_name='Field key', header=1)
ot
# Out:
#      southafrica_ghs-2.1_display  \
# 0    southafrica_ghs-2.2_display
# 1    southafrica_ghs-2.3_display
# 2    southafrica_ghs-2.4_display
# 3    southafrica_ghs-2.5_display
# 4    southafrica_ghs-2.6_display
# 5    southafrica_ghs-2.7_display
# 6    southafrica_ghs-2.8_display
# 7    southafrica_ghs-2.9_display
# 8   southafrica_ghs-2.10_display
# 9   southafrica_ghs-2.11_display
# 10  southafrica_ghs-2.12_display
# 11  southafrica_ghs-2.13_display
# 12  southafrica_ghs-2.14_display
# 13  southafrica_ghs-2.15_display
# 14  southafrica_ghs-2.16_display
# 15  southafrica_ghs-2.17_display
# 16   southafrica_ghs-3.1_display
# 17   southafrica_ghs-3.2_display
# 18   southafrica_ghs-3.3_display
# 19   southafrica_ghs-3.4_display
# 20   southafrica_ghs-3.5_display
# 21   southafrica_ghs-3.6_display
# 22   southafrica_ghs-3.7_display
# 23   southafrica_ghs-3.8_display
# 24   southafrica_ghs-3.9_display
# 25  southafrica_ghs-3.10_display
# 26   southafrica_ghs-4.1_display
# 27   southafrica_ghs-4.2_display
#
#                                             Explosive
# 0                                       Flammable gas
# 1                                             Aerosol
# 2                                       Oxidizing gas
# 3                      Dissolved gas / Compressed gas
# 4                                    Flammable liquid
# 5                                     Flammable solid
# 6                             Self-reactive substance
# 7                                   Pyrophoric liquid
# 8                                    Pyrophoric solid
# 9                              Self-heating substance
# 10        Emits flammable gases in contact with water
# 11                                   Oxidizing liquid
# 12                                    Oxidizing solid
# 13                                   Organic peroxide
# 14                                Corrosive to metals
# 15                             Desensitized explosive
# 16           Acute toxicity: oral; dermal; inhalation
# 17                          Skin corrosion/irritation
# 18                  Serious eye damage/eye irritation
# 19                                      Sensitization
# 20                             Germ cell mutagenicity
# 21                                    Carcinogenicity
# 22                              Reproductive toxicity
# 23    Specific target organ toxicity, single exposure
# 24  Specific target organ toxicity, repeated exposure
# 25                                  Aspiration hazard
# 26               Hazardous to the aquatic environment
# 27                       Hazardous to the ozone layer

# %%
bbd = pd.DataFrame()
for i in ot['southafrica_ghs-2.1_display']:
    bbd[i] = ""

# %%
# joining original data with output file template
full = pd.concat([df1, bbd])
full
# Out:
#       CAS No.                                      Chemical name  \
# 0      192337  Butyl 2,3-epoxypropyl ether, see Butyl glycidy...
# 1      292142  Cyclohexylidene hydroperoxide, see Cyclohexano...
# 2      698078                                 Potassium chlorate
# 3     1304222  Hydroxylamine hydrochloride, see Hydroxylammon...
# 4     1817789       trans-1-Methyl-4-(1-methylvinyl) cyclohexene
# ..        ...                                                ...
# 528   99-35-4  1,3,5-Trinitrobenzene, dry or wetted with less...
# 529  993-16-8      Methyltin trichloride | Methyltin trichloride
# 530   CAS No.                                      Chemical name
# 531         t  Diactoxydibuytyl stannane, see Dibutyl-tin di(...
# 532        –  Aluminium alkyls | Aluminium powder (stabilize...
#
#                                           Hazard class  \
# 0     | Flam liquid 3,Carcinogen 2,Mutagen 2,Skin s...
# 1
# 2                           Oxid solid 1,Chron aquat 2
# 3                                       | Metal corr 1
# 4    Flam liquid 3,Skin irritant 2,Skin sens 1,Acut...
# ..                                                 ...
# 528  Explosive 1.1D,Acute tox 3,(oral),Acute aquati...
# 529                  Mutagen 2,Repod tox 2 | Mutagen 2
# 530                                       Hazard class
# 531
# 532  Pyro liquid 1,Skin corr 1B | Water-react 2,Fla...
#
#                                                  NOTES  \
# 0                                                  |
# 1
# 2    A powerful oxidizer and vey reactive material....
# 3                                                  |
# 4
# ..                                                 ...
# 528  A powerful high explosive that has more shatte...
# 529  Not hazardous for transport. | Not hazardous f...
# 530                                              NOTES
# 531
# 532    |   |   |   |   |   |   |   | This classific...
#
#     southafrica_ghs-2.2_display southafrica_ghs-2.3_display  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 528                         NaN                         NaN
# 529                         NaN                         NaN
# 530                         NaN                         NaN
# 531                         NaN                         NaN
# 532                         NaN                         NaN
#
#     southafrica_ghs-2.4_display southafrica_ghs-2.5_display  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 528                         NaN                         NaN
# 529                         NaN                         NaN
# 530                         NaN                         NaN
# 531                         NaN                         NaN
# 532                         NaN                         NaN
#
#     southafrica_ghs-2.6_display southafrica_ghs-2.7_display  ...  \
# 0                           NaN                         NaN  ...
# 1                           NaN                         NaN  ...
# 2                           NaN                         NaN  ...
# 3                           NaN                         NaN  ...
# 4                           NaN                         NaN  ...
# ..                          ...                         ...  ...
# 528                         NaN                         NaN  ...
# 529                         NaN                         NaN  ...
# 530                         NaN                         NaN  ...
# 531                         NaN                         NaN  ...
# 532                         NaN                         NaN  ...
#
#     southafrica_ghs-3.3_display southafrica_ghs-3.4_display  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 528                         NaN                         NaN
# 529                         NaN                         NaN
# 530                         NaN                         NaN
# 531                         NaN                         NaN
# 532                         NaN                         NaN
#
#     southafrica_ghs-3.5_display southafrica_ghs-3.6_display  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 528                         NaN                         NaN
# 529                         NaN                         NaN
# 530                         NaN                         NaN
# 531                         NaN                         NaN
# 532                         NaN                         NaN
#
#     southafrica_ghs-3.7_display southafrica_ghs-3.8_display  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 528                         NaN                         NaN
# 529                         NaN                         NaN
# 530                         NaN                         NaN
# 531                         NaN                         NaN
# 532                         NaN                         NaN
#
#     southafrica_ghs-3.9_display southafrica_ghs-3.10_display  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
# ..                          ...                          ...
# 528                         NaN                          NaN
# 529                         NaN                          NaN
# 530                         NaN                          NaN
# 531                         NaN                          NaN
# 532                         NaN                          NaN
#
#     southafrica_ghs-4.1_display southafrica_ghs-4.2_display
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 528                         NaN                         NaN
# 529                         NaN                         NaN
# 530                         NaN                         NaN
# 531                         NaN                         NaN
# 532                         NaN                         NaN
#
# [533 rows x 32 columns]

# %%
# short version of strings mapped to full versions
dict ={
    'sens':'Sensitivity',
    'corr':'corrosion',
    'oxid':'Oxidizing',
    'tox':'toxicity',
    'perox':'peroxide',
    'reprod':'reproductive',
    'haz':'hazard',
    'Mutagen':'mutagenicity',
    'Pyro':'Pyrophoric',
    'Self-react':'Self-reactive',
    'Aspirate':'Aspiration',
    'Reprod':'Reproductive',
    'STOT repeat': 'Specific target organ toxicity, repeated exposure',
    'STOT single': 'Specific target organ toxicity, single exposure',
    'Org perox':'Organic peroxid'
}

# %%
# replace short strings
full['commentTest'] = full['Hazard class'].replace(dict, regex=True)

# %%
import re
import difflib
words = ot['Explosive'].tolist()
# methods to find closest matching strings
def find_close(a):
    arr = (a.split(","))
    f = []
    for w in arr:
        a = difflib.get_close_matches(w, words, n=1,cutoff=0.6)
        f.append(a)
    return f

# methods to find closest matching strings and the hazard classification number
def find_close_with_number(a):
    arr = (a.split(","))
    f = []
    for w in arr:
        a = difflib.get_close_matches(w, words, n=1,cutoff=0.6)
        ''.join(a)
        if re.search(r'\d+', w) != None:
            i = int(re.search(r'\d+', w).group())
            a = "{}{}".format(a, i)
            print(a)
        f.append(a)
    return f

# %%
el =0
dic = {}
for a in full['commentTest']:
    dic[full['CAS No.'][el]] = find_close(a)
    el=el+1

# %%
main = ot.set_index('southafrica_ghs-2.1_display').T.to_dict('list')

# %%
# assign each CAS number a list of field types it has
from collections import defaultdict
assigned = defaultdict(list)
for key, values in main.items():
    for k,v in dic.items():
        if values in v:
            assigned[k].append(key)

# %%
# based on the assigned list, input Category into according hazard type fields
for key, values in assigned.items():
    for v in values:
        i = full.index[full['CAS No.'] == key]
        full[v].loc[i]='Category'

# %%
full
# Out:
#       CAS No.                                      Chemical name  \
# 0      192337  Butyl 2,3-epoxypropyl ether, see Butyl glycidy...
# 1      292142  Cyclohexylidene hydroperoxide, see Cyclohexano...
# 2      698078                                 Potassium chlorate
# 3     1304222  Hydroxylamine hydrochloride, see Hydroxylammon...
# 4     1817789       trans-1-Methyl-4-(1-methylvinyl) cyclohexene
# ..        ...                                                ...
# 528   99-35-4  1,3,5-Trinitrobenzene, dry or wetted with less...
# 529  993-16-8      Methyltin trichloride | Methyltin trichloride
# 530   CAS No.                                      Chemical name
# 531         t  Diactoxydibuytyl stannane, see Dibutyl-tin di(...
# 532        –  Aluminium alkyls | Aluminium powder (stabilize...
#
#                                           Hazard class  \
# 0     | Flam liquid 3,Carcinogen 2,Mutagen 2,Skin s...
# 1
# 2                           Oxid solid 1,Chron aquat 2
# 3                                       | Metal corr 1
# 4    Flam liquid 3,Skin irritant 2,Skin sens 1,Acut...
# ..                                                 ...
# 528  Explosive 1.1D,Acute tox 3,(oral),Acute aquati...
# 529                  Mutagen 2,Repod tox 2 | Mutagen 2
# 530                                       Hazard class
# 531
# 532  Pyro liquid 1,Skin corr 1B | Water-react 2,Fla...
#
#                                                  NOTES  \
# 0                                                  |
# 1
# 2    A powerful oxidizer and vey reactive material....
# 3                                                  |
# 4
# ..                                                 ...
# 528  A powerful high explosive that has more shatte...
# 529  Not hazardous for transport. | Not hazardous f...
# 530                                              NOTES
# 531
# 532    |   |   |   |   |   |   |   | This classific...
#
#     southafrica_ghs-2.2_display southafrica_ghs-2.3_display  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 528                         NaN                         NaN
# 529                         NaN                         NaN
# 530                         NaN                         NaN
# 531                         NaN                         NaN
# 532                         NaN                         NaN
#
#     southafrica_ghs-2.4_display southafrica_ghs-2.5_display  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 528                         NaN                         NaN
# 529                         NaN                         NaN
# 530                         NaN                         NaN
# 531                         NaN                         NaN
# 532                         NaN                         NaN
#
#     southafrica_ghs-2.6_display southafrica_ghs-2.7_display  ...  \
# 0                      Category                         NaN  ...
# 1                           NaN                         NaN  ...
# 2                           NaN                         NaN  ...
# 3                           NaN                         NaN  ...
# 4                      Category                         NaN  ...
# ..                          ...                         ...  ...
# 528                         NaN                         NaN  ...
# 529                         NaN                         NaN  ...
# 530                         NaN                         NaN  ...
# 531                         NaN                         NaN  ...
# 532                         NaN                         NaN  ...
#
#     southafrica_ghs-3.4_display southafrica_ghs-3.5_display  \
# 0                           NaN                    Category
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 528                         NaN                         NaN
# 529                         NaN                    Category
# 530                         NaN                         NaN
# 531                         NaN                         NaN
# 532                         NaN                    Category
#
#     southafrica_ghs-3.6_display southafrica_ghs-3.7_display  \
# 0                      Category                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 528                         NaN                    Category
# 529                         NaN                         NaN
# 530                         NaN                         NaN
# 531                         NaN                         NaN
# 532                    Category                    Category
#
#     southafrica_ghs-3.8_display southafrica_ghs-3.9_display  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 528                         NaN                         NaN
# 529                         NaN                         NaN
# 530                         NaN                         NaN
# 531                         NaN                         NaN
# 532                    Category                         NaN
#
#     southafrica_ghs-3.10_display southafrica_ghs-4.1_display  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
# ..                           ...                         ...
# 528                          NaN                         NaN
# 529                          NaN                         NaN
# 530                          NaN                         NaN
# 531                          NaN                         NaN
# 532                     Category                         NaN
#
#     southafrica_ghs-4.2_display  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ..                          ...
# 528                         NaN
# 529                         NaN
# 530                         NaN
# 531                         NaN
# 532                         NaN
#
#                                            commentTest
# 0     | Flam liquid 3,Carcinogen 2,mutagenicity 2,S...
# 1
# 2                           Oxid solid 1,Chron aquat 2
# 3                                  | Metal corrosion 1
# 4    Flam liquid 3,Skin irritant 2,Skin Sensitivity...
# ..                                                 ...
# 528  Explosive 1.1D,Acute toxicity 3,(oral),Acute a...
# 529   mutagenicity 2,Repod toxicity 2 | mutagenicity 2
# 530                                       Hazard class
# 531
# 532  Pyrophoric liquid 1,Skin corrosion 1B | Water-...
#
# [533 rows x 33 columns]

# %%
full['Hazard class'] = full['commentTest']
full.drop('commentTest',axis=1)
# Out:
#       CAS No.                                      Chemical name  \
# 0      192337  Butyl 2,3-epoxypropyl ether, see Butyl glycidy...
# 1      292142  Cyclohexylidene hydroperoxide, see Cyclohexano...
# 2      698078                                 Potassium chlorate
# 3     1304222  Hydroxylamine hydrochloride, see Hydroxylammon...
# 4     1817789       trans-1-Methyl-4-(1-methylvinyl) cyclohexene
# ..        ...                                                ...
# 528   99-35-4  1,3,5-Trinitrobenzene, dry or wetted with less...
# 529  993-16-8      Methyltin trichloride | Methyltin trichloride
# 530   CAS No.                                      Chemical name
# 531         t  Diactoxydibuytyl stannane, see Dibutyl-tin di(...
# 532        –  Aluminium alkyls | Aluminium powder (stabilize...
#
#                                           Hazard class  \
# 0     | Flam liquid 3,Carcinogen 2,mutagenicity 2,S...
# 1
# 2                           Oxid solid 1,Chron aquat 2
# 3                                  | Metal corrosion 1
# 4    Flam liquid 3,Skin irritant 2,Skin Sensitivity...
# ..                                                 ...
# 528  Explosive 1.1D,Acute toxicity 3,(oral),Acute a...
# 529   mutagenicity 2,Repod toxicity 2 | mutagenicity 2
# 530                                       Hazard class
# 531
# 532  Pyrophoric liquid 1,Skin corrosion 1B | Water-...
#
#                                                  NOTES  \
# 0                                                  |
# 1
# 2    A powerful oxidizer and vey reactive material....
# 3                                                  |
# 4
# ..                                                 ...
# 528  A powerful high explosive that has more shatte...
# 529  Not hazardous for transport. | Not hazardous f...
# 530                                              NOTES
# 531
# 532    |   |   |   |   |   |   |   | This classific...
#
#     southafrica_ghs-2.2_display southafrica_ghs-2.3_display  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 528                         NaN                         NaN
# 529                         NaN                         NaN
# 530                         NaN                         NaN
# 531                         NaN                         NaN
# 532                         NaN                         NaN
#
#     southafrica_ghs-2.4_display southafrica_ghs-2.5_display  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 528                         NaN                         NaN
# 529                         NaN                         NaN
# 530                         NaN                         NaN
# 531                         NaN                         NaN
# 532                         NaN                         NaN
#
#     southafrica_ghs-2.6_display southafrica_ghs-2.7_display  ...  \
# 0                      Category                         NaN  ...
# 1                           NaN                         NaN  ...
# 2                           NaN                         NaN  ...
# 3                           NaN                         NaN  ...
# 4                      Category                         NaN  ...
# ..                          ...                         ...  ...
# 528                         NaN                         NaN  ...
# 529                         NaN                         NaN  ...
# 530                         NaN                         NaN  ...
# 531                         NaN                         NaN  ...
# 532                         NaN                         NaN  ...
#
#     southafrica_ghs-3.3_display southafrica_ghs-3.4_display  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 528                         NaN                         NaN
# 529                         NaN                         NaN
# 530                         NaN                         NaN
# 531                         NaN                         NaN
# 532                         NaN                         NaN
#
#     southafrica_ghs-3.5_display southafrica_ghs-3.6_display  \
# 0                      Category                    Category
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 528                         NaN                         NaN
# 529                    Category                         NaN
# 530                         NaN                         NaN
# 531                         NaN                         NaN
# 532                    Category                    Category
#
#     southafrica_ghs-3.7_display southafrica_ghs-3.8_display  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 528                    Category                         NaN
# 529                         NaN                         NaN
# 530                         NaN                         NaN
# 531                         NaN                         NaN
# 532                    Category                    Category
#
#     southafrica_ghs-3.9_display southafrica_ghs-3.10_display  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
# ..                          ...                          ...
# 528                         NaN                          NaN
# 529                         NaN                          NaN
# 530                         NaN                          NaN
# 531                         NaN                          NaN
# 532                         NaN                     Category
#
#     southafrica_ghs-4.1_display southafrica_ghs-4.2_display
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 528                         NaN                         NaN
# 529                         NaN                         NaN
# 530                         NaN                         NaN
# 531                         NaN                         NaN
# 532                         NaN                         NaN
#
# [533 rows x 32 columns]

# %%
t =full['NOTES'][0]
t2=full['NOTES'][31]
t3=full['NOTES'][111]
t4=full['NOTES'][507]

# %%
full.loc[full['NOTES'] == t, 'NOTES'] = ''
full.loc[full['NOTES'] == t2, 'NOTES'] = ''
full.loc[full['NOTES'] == t3, 'NOTES'] = ''
full.loc[full['NOTES'] == t4, 'NOTES'] = ''

# %%
full.drop(index=530,axis=0,inplace=True)
full.drop('commentTest', axis=1, inplace=True)

# %%
full
# Out:
#       CAS No.                                      Chemical name  \
# 0      192337  Butyl 2,3-epoxypropyl ether, see Butyl glycidy...
# 1      292142  Cyclohexylidene hydroperoxide, see Cyclohexano...
# 2      698078                                 Potassium chlorate
# 3     1304222  Hydroxylamine hydrochloride, see Hydroxylammon...
# 4     1817789       trans-1-Methyl-4-(1-methylvinyl) cyclohexene
# ..        ...                                                ...
# 527   98-95-3                                       Nitrobenzene
# 528   99-35-4  1,3,5-Trinitrobenzene, dry or wetted with less...
# 529  993-16-8      Methyltin trichloride | Methyltin trichloride
# 531         t  Diactoxydibuytyl stannane, see Dibutyl-tin di(...
# 532        –  Aluminium alkyls | Aluminium powder (stabilize...
#
#                                           Hazard class  \
# 0     | Flam liquid 3,Carcinogen 2,mutagenicity 2,S...
# 1
# 2                           Oxid solid 1,Chron aquat 2
# 3                                  | Metal corrosion 1
# 4    Flam liquid 3,Skin irritant 2,Skin Sensitivity...
# ..                                                 ...
# 527  Carcinogen 2,Reproductive toxicity 2,Acute tox...
# 528  Explosive 1.1D,Acute toxicity 3,(oral),Acute a...
# 529   mutagenicity 2,Repod toxicity 2 | mutagenicity 2
# 531
# 532  Pyrophoric liquid 1,Skin corrosion 1B | Water-...
#
#                                                  NOTES  \
# 0
# 1
# 2    A powerful oxidizer and vey reactive material....
# 3
# 4
# ..                                                 ...
# 527
# 528  A powerful high explosive that has more shatte...
# 529  Not hazardous for transport. | Not hazardous f...
# 531
# 532    |   |   |   |   |   |   |   | This classific...
#
#     southafrica_ghs-2.2_display southafrica_ghs-2.3_display  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 527                         NaN                         NaN
# 528                         NaN                         NaN
# 529                         NaN                         NaN
# 531                         NaN                         NaN
# 532                         NaN                         NaN
#
#     southafrica_ghs-2.4_display southafrica_ghs-2.5_display  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 527                         NaN                         NaN
# 528                         NaN                         NaN
# 529                         NaN                         NaN
# 531                         NaN                         NaN
# 532                         NaN                         NaN
#
#     southafrica_ghs-2.6_display southafrica_ghs-2.7_display  ...  \
# 0                      Category                         NaN  ...
# 1                           NaN                         NaN  ...
# 2                           NaN                         NaN  ...
# 3                           NaN                         NaN  ...
# 4                      Category                         NaN  ...
# ..                          ...                         ...  ...
# 527                         NaN                         NaN  ...
# 528                         NaN                         NaN  ...
# 529                         NaN                         NaN  ...
# 531                         NaN                         NaN  ...
# 532                         NaN                         NaN  ...
#
#     southafrica_ghs-3.3_display southafrica_ghs-3.4_display  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 527                         NaN                         NaN
# 528                         NaN                         NaN
# 529                         NaN                         NaN
# 531                         NaN                         NaN
# 532                         NaN                         NaN
#
#     southafrica_ghs-3.5_display southafrica_ghs-3.6_display  \
# 0                      Category                    Category
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 527                         NaN                    Category
# 528                         NaN                         NaN
# 529                    Category                         NaN
# 531                         NaN                         NaN
# 532                    Category                    Category
#
#     southafrica_ghs-3.7_display southafrica_ghs-3.8_display  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 527                    Category                    Category
# 528                    Category                         NaN
# 529                         NaN                         NaN
# 531                         NaN                         NaN
# 532                    Category                    Category
#
#     southafrica_ghs-3.9_display southafrica_ghs-3.10_display  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
# ..                          ...                          ...
# 527                         NaN                          NaN
# 528                         NaN                          NaN
# 529                         NaN                          NaN
# 531                         NaN                          NaN
# 532                         NaN                     Category
#
#     southafrica_ghs-4.1_display southafrica_ghs-4.2_display
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ..                          ...                         ...
# 527                         NaN                         NaN
# 528                         NaN                         NaN
# 529                         NaN                         NaN
# 531                         NaN                         NaN
# 532                         NaN                         NaN
#
# [532 rows x 32 columns]

# %%
# export to excel file
full.to_excel("try.xlsx")
